# %%
import pandas as pd
import pymysql

df = pd.read_csv("alquiler.csv")

# Crear tipo_vivienda a partir de las columnas booleanas de Pablo
lista_tipos_vivienda = ["piso", "atico", "estudio", "apartamento", "duplex", "chalet", "finca", "loft"]

df["tipo_vivienda"] = df[lista_tipos_vivienda].to_numpy().argmax(axis=1)
df["tipo_vivienda"] = df["tipo_vivienda"].apply(lambda val: lista_tipos_vivienda[val])

conexion = pymysql.connect(
    host="localhost",
    user="root",
    password="Destroyerl0",
    database="propiedades_de_alquiler",
    charset="utf8mb4"
)

cursor = conexion.cursor()

for _, fila in df.iterrows():
    sql = """
    INSERT INTO anuncios (titulo, precio, ubicacion, habitaciones, baños, metros, tipo_vivienda, superficie_construida, link)
    VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)
    """
    datos = (
        fila["titulo"],
        float(fila["precio"]) if not pd.isna(fila["precio"]) else None,
        fila["ubicacion"],
        int(fila["habitaciones"]) if not pd.isna(fila["habitaciones"]) else None,
        int(fila["baños"]) if not pd.isna(fila["baños"]) else None,
        int(fila["metros"]) if not pd.isna(fila["metros"]) else None,
        fila["tipo_vivienda"],
        int(fila["superficie_construida"]) if not pd.isna(fila["superficie_construida"]) else None,
        fila["link"]
    )
    cursor.execute(sql, datos)

conexion.commit()
cursor.close()
conexion.close()

# %%
df[["tipo_vivienda"] + lista_tipos_vivienda]

#solo es una comprobacion
# Out:
#     tipo_vivienda   piso  atico  estudio  apartamento  duplex  chalet  finca  \
# 0            piso   True  False    False        False   False   False  False
# 1            piso   True  False    False        False   False   False  False
# 2            piso   True  False    False        False   False   False  False
# 3     apartamento  False  False    False         True   False   False  False
# 4            piso   True  False    False        False   False   False  False
# ..            ...    ...    ...      ...          ...     ...     ...    ...
# 496          piso   True  False    False        False   False   False  False
# 497          piso   True  False    False        False   False   False  False
# 498   apartamento  False  False    False         True   False   False  False
# 499         atico  False   True    False        False   False   False  False
# 500          piso   True  False    False        False   False   False  False
#
#       loft
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# ..     ...
# 496  False
# 497  False
# 498  False
# 499  False
# 500  False
#
# [501 rows x 9 columns]
